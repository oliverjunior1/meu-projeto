# %% [markdown]
# <a href="https://colab.research.google.com/github/oliverjunior1/meu-projeto/blob/main/Visao_computacional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Visão computacional

# %%
import cv2 # OpenCV

# %%
imagem = cv2.imread('/content/sample_data/workplace-1245776_1920.jpg')
