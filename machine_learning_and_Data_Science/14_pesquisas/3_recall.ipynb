# %% [markdown]
# O recall (também chamado de sensibilidade ou true positive rate) é uma métrica muito importante em Machine Learning para problemas de classificação.
#
# Ele mede:
#
# “Dos casos realmente positivos, quantos o modelo conseguiu encontrar?”

# %%
from sklearn.metrics import recall_score

# %%
y_real = [1,1,1,1,0,0,0]
y_pred = [1,1,0,1,0,1,0]

# %%
# Out:
# 0.75

# %% [markdown]
# # Interpretação
# Deu 75% de casos positivos reais.

# %% [markdown]
# # Recall:
#
# - ✅ mede capacidade de encontrar positivos
# - ✅ reduz falsos negativos
# - ✅ é crucial em problemas críticos
# - ✅ funciona junto com precisão e F1-score
#
# Frase simples para decorar
#
# Recall = “De tudo que era positivo, quanto eu consegui encontrar?”
