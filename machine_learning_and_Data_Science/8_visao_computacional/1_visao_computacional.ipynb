# %% [markdown]
# ### Visão computacional

# %% [markdown]
# Detecção de faces

# %%
! pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
! py -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\olive\appdata\local\programs\python\python313\lib\site-packages (25.3)
# Collecting pip
#   Using cached pip-26.1.1-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.1.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# Successfully installed pip-26.1.1

# %%
! pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in C:\Users\Olive\AppData\Local\Programs\Python\Python313\Lib\site-packages (from opencv-python) (2.2.3)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    --- ------------------------------------ 3.4/40.2 MB 29.8 MB/s eta 0:00:02
#    ------- -------------------------------- 7.6/40.2 MB 24.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.0/40.2 MB 21.5 MB/s eta 0:00:02
#    -------------- ------------------------- 14.9/40.2 MB 19.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.8/40.2 MB 17.7 MB/s eta 0:00:02
#    ------------------ --------------------- 18.4/40.2 MB 15.3 MB/s eta 0:00:02
#    ------------------- -------------------- 19.9/40.2 MB 14.2 MB/s eta 0:00:02
#    --------------------- ------------------ 21.5/40.2 MB 13.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.3/40.2 MB 12.7 MB/s eta 0:00:02
#    ------------------------- -------------- 25.2/40.2 MB 12.3 MB/s eta 0:00:02
#    -------------------------- ------------- 27.0/40.2 MB 11.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 28.8/40.2 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 30.9/40.2 MB 11.5 MB/s eta 0:00:01
#    -------------------------------- ------- 33.0/40.2 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 35.1/40.2 MB 11.2 MB/s eta 0:00:01
#    ------------------------------------- -- 37.2/40.2 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  39.3/40.2 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 10.6 MB/s  0:00:03
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in C:\Users\Olive\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in C:\Users\Olive\AppData\Local\Programs\Python\Python313\Lib\site-packages (from opencv-python) (2.2.3)

# %%
import sys
# !{sys.executable} -m pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\olive\anaconda3\lib\site-packages (from opencv-python) (2.1.3)
# Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
imagem = cv2.imread('workplace-1245776_1920.jpg')
