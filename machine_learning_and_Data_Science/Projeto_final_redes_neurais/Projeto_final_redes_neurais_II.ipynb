# %% [markdown]
# # Imports

# %%
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
# Out:
# c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (7.3.0)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# ### Load data

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ### Normalização

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ### One-hot encoding

# %%
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# %% [markdown]
# - Modelo 1 - MLP

# %%
X_train_flat = X_train.reshape(-1, 28*28)
X_test_flat = X_test.reshape(-1, 28*28)

# %%
mlp = Sequential()
mlp.add(Dense(128, activation='relu', input_shape=(784,)))
mlp.add(Dense(64, activation='relu'))
mlp.add(Dense(10, activation='softmax'))
# Out:
# c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
mlp.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history_mlp = mlp.fit(
    X_train_flat, y_train_cat,
    epochs=10,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - accuracy: 0.8169 - loss: 0.5126 - val_accuracy: 0.8130 - val_loss: 0.5006
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.8602 - loss: 0.3798 - val_accuracy: 0.8660 - val_loss: 0.3668
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8759 - loss: 0.3375 - val_accuracy: 0.8628 - val_loss: 0.3843
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 22s 13ms/step - accuracy: 0.8828 - loss: 0.3158 - val_accuracy: 0.8659 - val_loss: 0.3574
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.8883 - loss: 0.2986 - val_accuracy: 0.8796 - val_loss: 0.3301
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.8948 - loss: 0.2830 - val_accuracy: 0.8760 - val_loss: 0.3472
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.8983 - loss: 0.2716 - val_accuracy: 0.8824 - val_loss: 0.3326
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9040 - loss: 0.2596 - val_accuracy: 0.8837 - val_loss: 0.3319
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.9059 - loss: 0.2514 - val_accuracy: 0.8858 - val_loss: 0.3234
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.9095 - loss: 0.2397 - val_accuracy: 0.8798 - val_loss: 0.3417

# %% [markdown]
# - Modelo 2 - CNN

# %%
X_train_cnn = X_train.reshape(-1, 28, 28, 1)
X_test_cnn = X_test.reshape(-1, 28, 28, 1)

# %%
cnn = Sequential()

cnn.add(Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)))
cnn.add(MaxPooling2D((2,2)))
# Out:
# c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(Conv2D(64, (3,3), activation='relu'))
cnn.add(MaxPooling2D((2,2)))

# %%
cnn.add(Flatten())
cnn.add(Dense(64, activation='relu'))
cnn.add(Dense(10, activation='softmax'))

# %%
cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_cnn = cnn.fit(
    X_train_cnn, y_train_cat,
    epochs=10,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 85s 45ms/step - accuracy: 0.8185 - loss: 0.4979 - val_accuracy: 0.8438 - val_loss: 0.4219
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 58s 39ms/step - accuracy: 0.8791 - loss: 0.3348 - val_accuracy: 0.8809 - val_loss: 0.3291
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 64s 43ms/step - accuracy: 0.8956 - loss: 0.2869 - val_accuracy: 0.8985 - val_loss: 0.2806
# Epoch 4/10
#  391/1500 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9087 - loss: 0.2427

# %% [markdown]
# - Avaliação
