# %% [markdown]
# ---
#
# Reconecte ao Drive.

# %%
import os
DRIVE_DIRECTORY = "curso_ml"
DRIVE_DIRECTORY = os.path.join("/content/drive/MyDrive", DRIVE_DIRECTORY)

# %% [markdown]
# ---

# %%
# !pip install pyECLAT

# %%
import pandas as pd

from pyECLAT import ECLAT

# %% [markdown]
# ## Algoritmo ECLAT

# %% [markdown]
# Carregue a lista de compras a partir do arquivo `itemlist.txt` na pasta do Drive, como um DataFrame do Pandas, lembre-se de selecionar o delimitador adequado.

# %%
base = pd.read_csv(os.path.join(DRIVE_DIRECTORY, 'itemlist.txt'), delimiter=';', header=None)
base
# Out:
#                                     0                         1   \
# 0          RED RETROSPOT CHARLOTTE BAG   LUNCH BAG RED RETROSPOT
# 1      PACK OF 72 RETROSPOT CAKE CASES    JUMBO STORAGE BAG SUKI
# 2      PACK OF 72 RETROSPOT CAKE CASES    JUMBO STORAGE BAG SUKI
# 3             ALARM CLOCK BAKELIKE RED  JAM MAKING SET WITH JARS
# 4          RED RETROSPOT CHARLOTTE BAG        LUNCH BAG WOODLAND
# ...                                ...                       ...
# 12783                    PARTY BUNTING                       NaN
# 12784          JUMBO BAG RED RETROSPOT                       NaN
# 12785                          POSTAGE                       NaN
# 12786                          POSTAGE                       NaN
# 12787          JUMBO BAG PINK POLKADOT                       NaN
#
#                                    2                                3   \
# 0                  LUNCH BAG WOODLAND          LUNCH BAG  BLACK SKULL.
# ...

# %% [markdown]
# Instancie uma classe de ECLAT, informando o DataFrame.

# %%
eclat = ECLAT(data=base)

# %% [markdown]
# Exiba o DataFrame no formato binário.

# %%
eclat.df_bin
# Out:
#        LUNCH BAG WOODLAND  ALARM CLOCK BAKELIKE RED  LUNCH BAG APPLE DESIGN  \
# 0                       1                         1                       1
# 1                       1                         1                       1
# 2                       1                         1                       1
# 3                       0                         1                       1
# 4                       1                         1                       0
# ...                   ...                       ...                     ...
# 12783                   0                         0                       0
# 12784                   0                         0                       0
# 12785                   0                         0                       0
# 12786                   0                         0                       0
# 12787                   0                         0                       0
#
#        JAM MAKING SET PRINTED  LUNCH BAG SUKI DESIGN  \
# ...

# %% [markdown]
# Exiba os valores das colunas, que representam os itens deste problema.

# %%
___

# %% [markdown]
# Ajuste o algoritmo ECLAT, utilizando o mesmo suporte mínimo do exercício do algoritmo apriori ($0.02$), e solicitando `min_combination=1` e `max_combination=3`.

# %%
indices, support = ___

# %% [markdown]
# Exiba os itens e suas respectivas transações.

# %%
___

# %% [markdown]
# Quantos itemsets foram gerados?

# %%
___

# %% [markdown]
# Exiba os itens e seus respectivos suportes.

# %%
___
