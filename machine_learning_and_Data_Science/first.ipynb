kB/s eta 0:00:02
#    -------------------------------------- - 9.4/9.9 MB 500.6 kB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 507.6 kB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 507.6 kB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 510.3 kB/s eta 0:00:00
# Downloading narwhals-2.18.0-py3-none-any.whl (444 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-2.18.0 plotly-6.6.0
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (6.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from plotly) (2.18.0)
# Requirement already satisfied: packaging in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from plotly) (24.0)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# **Exploração de dados**

# %%
base_credit = pd.read_csv('credit_risk_dataset.csv')
base_credit
# Out:
#        age  income person_home_ownership  person_emp_length      loan_intent  \
# 0       22   59000                  RENT              123.0         PERSONAL
# 1       21    9600                   OWN                5.0        EDUCATION
# 2       25    9600              MORTGAGE                1.0          MEDICAL
# 3       23   65500                  RENT                4.0          MEDICAL
# 4       24   54400                  RENT                8.0          MEDICAL
# ...    ...     ...                   ...                ...              ...
# 32576   57   53000              MORTGAGE                1.0         PERSONAL
# 32577   54  120000              MORTGAGE                4.0         PERSONAL
# 32578   65   76000                  RENT                3.0  HOMEIMPROVEMENT
# 32579   56  150000              MORTGAGE                5.0         PERSONAL
# 32580   66   42000                  RENT                2.0          MEDICAL
#
#       loan_grade  loan_amnt  loan_int_rate  loan  loan_percent_income  \
# 0              D      35000          16.02     1                 0.59
# 1              B       1000          11.14     0                 0.10
# 2              C       5500          12.87     1                 0.57
# 3              C      35000          15.23     1                 0.53
# 4              C      35000          14.27     1                 0.55
# ...          ...        ...            ...   ...                  ...
# 32576          C       5800          13.16     0                 0.11
# 32577          A      17625           7.49     0                 0.15
# 32578          B      35000          10.99     1                 0.46
# 32579          B      15000          11.48     0                 0.10
# 32580          B       6475           9.99     0                 0.15
#
#       cb_person_default_on_file  cb_person_cred_hist_length
# 0                             Y                           3
# 1                             N                           2
# 2                             N                           3
# 3                             N                           2
# 4                             Y                           4
# ...                         ...                         ...
# 32576                         N                          30
# 32577                         N                          19
# 32578                         N                          28
# 32579                         N                          26
# 32580                         N                          30
#
# [32581 rows x 12 columns]

# %%
base_credit.head()
# Out:
#    age  income person_home_ownership  person_emp_length loan_intent  \
# 0   22   59000                  RENT              123.0    PERSONAL
# 1   21    9600                   OWN                5.0   EDUCATION
# 2   25    9600              MORTGAGE                1.0     MEDICAL
# 3   23   65500                  RENT                4.0     MEDICAL
# 4   24   54400                  RENT                8.0     MEDICAL
#
#   loan_grade  loan_amnt  loan_int_rate  loan  loan_percent_income  \
# 0          D      35000          16.02     1                 0.59
# 1          B       1000          11.14     0                 0.10
# 2          C       5500          12.87     1                 0.57
# 3          C      35000          15.23     1                 0.53
# 4          C      35000          14.27     1                 0.55
#
#   cb_person_default_on_file  cb_person_cred_hist_length
# 0                         Y                           3
# 1                         N                           2
# 2                         N                           3
# 3                         N                           2
# 4                         Y                           4

# %%
base_credit.head(10)
# Out:
#    age  income person_home_ownership  person_emp_length loan_intent  \
# 0   22   59000                  RENT              123.0    PERSONAL
# 1   21    9600                   OWN                5.0   EDUCATION
# 2   25    9600              MORTGAGE                1.0     MEDICAL
# 3   23   65500                  RENT                4.0     MEDICAL
# 4   24   54400                  RENT                8.0     MEDICAL
# 5   21    9900                   OWN                2.0     VENTURE
# 6   26   77100                  RENT                8.0   EDUCATION
# 7   24   78956                  RENT                5.0     MEDICAL
# 8   24   83000                  RENT                8.0    PERSONAL
# 9   21   10000                   OWN                6.0     VENTURE
#
#   loan_grade  loan_amnt  loan_int_rate  loan  loan_percent_income  \
# 0          D      35000          16.02     1                 0.59
# 1          B       1000          11.14     0                 0.10
# 2          C       5500          12.87     1                 0.57
# 3          C      35000          15.23     1                 0.53
# 4          C      35000          14.27     1                 0.55
# 5          A       2500           7.14     1                 0.25
# 6          B      35000          12.42     1                 0.45
# 7          B      35000          11.11     1                 0.44
# 8          A      35000           8.90     1                 0.42
# 9          D       1600          14.74     1                 0.16
#
#   cb_person_default_on_file  cb_person_cred_hist_length
# 0                         Y                           3
# 1                         N                           2
# 2                         N                           3
# 3                         N                           2
# 4                         Y                           4
# 5                         N                           2
# 6                         N                           3
# 7                         N                           4
# 8                         N                           2
# 9                         N                           3

# %%
base_credit.tail()
# Out:
#        age  income person_home_ownership  person_emp_length      loan_intent  \
# 32576   57   53000              MORTGAGE                1.0         PERSONAL
# 32577   54  120000              MORTGAGE                4.0         PERSONAL
# 32578   65   76000                  RENT                3.0  HOMEIMPROVEMENT
# 32579   56  150000              MORTGAGE                5.0         PERSONAL
# 32580   66   42000                  RENT                2.0          MEDICAL
#
#       loan_grade  loan_amnt  loan_int_rate  loan  loan_percent_income  \
# 32576          C       5800          13.16     0                 0.11
# 32577          A      17625           7.49     0                 0.15
# 32578          B      35000          10.99     1                 0.46
# 32579          B      15000          11.48     0                 0.10
# 32580          B       6475           9.99     0                 0.15
#
#       cb_person_default_on_file  cb_person_cred_hist_length
# 32576                         N                          30
# 32577                         N                          19
# 32578                         N                          28
# 32579                         N                          26
# 32580                         N                          30

# %%
base_credit.tail(8)
# Out:
#        age  income person_home_ownership  person_emp_length      loan_intent  \
# 32573   56   90000              MORTGAGE                0.0         PERSONAL
# 32574   52   65004                  RENT                4.0         PERSONAL
# 32575   52   64500                  RENT                0.0        EDUCATION
# 32576   57   53000              MORTGAGE                1.0         PERSONAL
# 32577   54  120000              MORTGAGE                4.0         PERSONAL
# 32578   65   76000                  RENT                3.0  HOMEIMPROVEMENT
# 32579   56  150000              MORTGAGE                5.0         PERSONAL
# 32580   66   42000                  RENT                2.0          MEDICAL
#
#       loan_grade  loan_amnt  loan_int_rate  loan  loan_percent_income  \
# 32573          A       7200           6.17     0                 0.08
# 32574          D      20000          15.58     1                 0.31
# 32575          B       5000          11.26     0                 0.08
# 32576          C       5800          13.16     0                 0.11
# 32577          A      17625           7.49     0                 0.15
# 32578          B      35000          10.99     1                 0.46
# 32579          B      15000          11.48     0                 0.10
# 32580          B       6475           9.99     0                 0.15
#
#       cb_person_default_on_file  cb_person_cred_hist_length
# 32573                         N                          19
# 32574                         Y                          19
# 32575                         N                          20
# 32576                         N                          30
# 32577                         N                          19
# 32578                         N                          28
# 32579                         N                          26
# 32580                         N                          30

# %%
base_credit.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# 50%        10.990000      0.000000             0.150000
# 75%        13.470000      0.000000             0.230000
# max        23.220000      1.000000             0.830000
#
#        cb_person_cred_hist_length
# count                32581.000000
# mean                     5.804211
# std                      4.055001
# min                      2.000000
# 25%                      3.000000
# 50%                      4.000000
# 75%                      8.000000
# max                     30.000000

# %%
base_credit[base_credit['income'] == 69995.685578]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 base_credit[base_credit['income'] == 69995.685578]
#
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'income'

# %%
base_credit[base_credit['loan'] <= 1.377630]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loan'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 base_credit[base_credit['loan'] <= 1.377630]
#
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'loan'

# %% [markdown]
# ### Visualização dos dados

# %%
base_credit.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# 50%        10.990000      0.000000             0.150000
# 75%        13.470000      0.000000             0.230000
# max        23.220000      1.000000             0.830000
#
#        cb_person_cred_hist_length
# count                32581.000000
# mean                     5.804211
# std                      4.055001
# min                      2.000000
# 25%                      3.000000
# 50%                      4.000000
# 75%                      8.000000
# max                     30.000000

# %%
np.unique(base_credit['loan_status'], return_counts = True)
# Out:
# (array([0, 1], dtype=int64), array([25473,  7108], dtype=int64))

# %%
sns.countplot(x = base_credit['loan_status'])
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
plt.hist(x = base_credit['person_age'])
# Out:
# (array([2.693e+04, 4.891e+03, 6.510e+02, 8.900e+01, 1.300e+01, 2.000e+00,
#         0.000e+00, 0.000e+00, 2.000e+00, 3.000e+00]),
#  array([ 20. ,  32.4,  44.8,  57.2,  69.6,  82. ,  94.4, 106.8, 119.2,
#         131.6, 144. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x = base_credit['person_income'])
# Out:
# (array([3.2542e+04, 3.3000e+01, 3.0000e+00, 2.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([4.0000e+03, 6.0360e+05, 1.2032e+06, 1.8028e+06, 2.4024e+06,
#         3.0020e+06, 3.6016e+06, 4.2012e+06, 4.8008e+06, 5.4004e+06,
#         6.0000e+06]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x = base_credit['loan_amnt'])
# Out:
# (array([5118., 9436., 7387., 3907., 2869., 1926.,  675.,  925.,  125.,
#          213.]),
#  array([  500.,  3950.,  7400., 10850., 14300., 17750., 21200., 24650.,
#         28100., 31550., 35000.]),
#  <BarContainer object of 10 artists>)

# %%
grafico = px.scatter_matrix(base_credit, dimensions=['age'])
grafico
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 grafico = px.scatter_matrix(base_credit, dimensions=['age'])
#       2 grafico
#
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\express\_chart_types.py:1628, in scatter_matrix(data_frame, dimensions, color, symbol, size, hover_name, hover_data, custom_data, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, title, subtitle, template, width, height)
#    1596 def scatter_matrix(
#    1597     data_frame=None,
#    1598     dimensions=None,
#    (...)   1620     height=None,
#    1621 ) -> go.Figure:
#    1622     """
#    1623     In a scatter plot matrix (or SPLOM), each row of `data_frame` is
#    1624     represented by a multiple symbol marks, one in each cell of a grid of
#    1625     2D scatter plots, which plot each pair of `dimensions` against each
#    1626     other.
#    1627     """
# -> 1628     return make_figure(
#    1629         args=locals(), constructor=go.Splom, layout_patch=dict(dragmode="select")
#    1630     )
#
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\express\_core.py:2511, in make_figure(args, constructor, trace_patch, layout_patch)
#    2508 layout_patch = layout_patch or {}
#    2509 apply_default_cascade(args, constructor=constructor)
# -> 2511 args = build_dataframe(args, constructor)
#    2512 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2513     args = process_dataframe_hierarchy(args)
#
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\express\_core.py:1757, in build_dataframe(args, constructor)
#    1754     args["color"] = None
#    1755 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1757 df_output, wide_id_vars = process_args_into_dataframe(
#    1758     args,
#    1759     wide_mode,
#    1760     var_name,
#    1761     value_name,
#    1762     is_pd_like,
#    1763     native_namespace,
#    1764 )
#    1765 df_output: nw.DataFrame
#    1766 # now that `df_output` exists and `args` contains only references, we complete
#    1767 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1768 # df_output
#
# File c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\express\_core.py:1358, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1356         if argument == "index":
#    1357             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1358         raise ValueError(err_msg)
#    1359 elif length and (actual_len := len(df_input)) != length:
#    1360     raise ValueError(
#    1361         "All arguments should have the same length. "
#    1362         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)   1369         )
#    1370     )
#
# ValueError: Value of 'dimensions_0' is not the name of a column in 'data_frame'. Expected one of ['person_age', 'person_income', 'person_home_ownership', 'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt', 'loan_int_rate', 'loan_status', 'loan_percent_income', 'cb_person_default_on_file', 'cb_person_cred_hist_length'] but received: age
