# %% [markdown]
# # Guia Completo de PyCaret com 5 Exemplos
#
# ## O que é PyCaret?
#
# PyCaret é uma biblioteca low-code de Machine Learning para Python.
#
# Ela automatiza:
# - treinamento;
# - comparação de modelos;
# - preprocessamento;
# - previsão;
# - análise de dados.
#
# Com poucas linhas de código é possível criar modelos completos.

# %% [markdown]
# # Instalação
#
# ```python
# pip install pycaret
# ```
#
# ou:
#
# ```python
# pip install pycaret[full]
# ```

# %% [markdown]
# # Exemplo 1 - Classificação
#
# ## Objetivo
# Prever categorias.
#
# Exemplos:
# - spam;
# - fraude;
# - aprovação de crédito.

# %%
! pip install pycaret

# %%
! pip install pycaret[full]
# Out:
# Collecting pycaret[full]
#   Using cached pycaret-3.3.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\olive\anaconda3\lib\site-packages (from pycaret[full]) (8.30.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\olive\anaconda3\lib\site-packages (from pycaret[full]) (8.1.5)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\olive\anaconda3\lib\site-packages (from pycaret[full]) (4.67.1)
# Collecting numpy<1.27,>=1.21 (from pycaret[full])
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\Olive\anaconda3\python.exe C:\Users\Olive\AppData\Local\Temp\pip-install-nimod8w4\numpy_c74fe7b5c6424d65a73d715e86c468c0\vendored-meson\meson\meson.py setup C:\Users\Olive\AppData\Local\Temp\pip-install-nimod8w4\numpy_c74fe7b5c6424d65a73d715e86c468c0 C:\Users\Olive\AppData\Local\Temp\pip-install-nimod8w4\numpy_c74fe7b5c6424d65a73d715e86c468c0\.mesonpy-ka0ii_j4 -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\Olive\AppData\Local\Temp\pip-install-nimod8w4\numpy_c74fe7b5c6424d65a73d715e86c468c0\.mesonpy-ka0ii_j4\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\Olive\AppData\Local\Temp\pip-install-nimod8w4\numpy_c74fe7b5c6424d65a73d715e86c468c0
#       Build dir: C:\Users\Olive\AppData\Local\Temp\pip-install-nimod8w4\numpy_c74fe7b5c6424d65a73d715e86c468c0\.mesonpy-ka0ii_j4
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not parse vswhere.exe output
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `cl /?` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `cc --version` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `gcc --version` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `clang --version` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `clang-cl /?` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `pgcc --version` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#
#       A full log can be found at C:\Users\Olive\AppData\Local\Temp\pip-install-nimod8w4\numpy_c74fe7b5c6424d65a73d715e86c468c0\.mesonpy-ka0ii_j4\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import sys

# !{sys.executable} -m pip install pycaret
# Out:
# Collecting pycaret
#   Using cached pycaret-3.3.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\olive\anaconda3\lib\site-packages (from pycaret) (8.30.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\olive\anaconda3\lib\site-packages (from pycaret) (8.1.5)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\olive\anaconda3\lib\site-packages (from pycaret) (4.67.1)
# Collecting numpy<1.27,>=1.21 (from pycaret)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + c:\Users\Olive\anaconda3\python.exe C:\Users\Olive\AppData\Local\Temp\pip-install-rq_w22ba\numpy_7879cad0f7b84bb99bf26e1c5bfbf0e2\vendored-meson\meson\meson.py setup C:\Users\Olive\AppData\Local\Temp\pip-install-rq_w22ba\numpy_7879cad0f7b84bb99bf26e1c5bfbf0e2 C:\Users\Olive\AppData\Local\Temp\pip-install-rq_w22ba\numpy_7879cad0f7b84bb99bf26e1c5bfbf0e2\.mesonpy-krpvwi7m -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\Olive\AppData\Local\Temp\pip-install-rq_w22ba\numpy_7879cad0f7b84bb99bf26e1c5bfbf0e2\.mesonpy-krpvwi7m\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\Olive\AppData\Local\Temp\pip-install-rq_w22ba\numpy_7879cad0f7b84bb99bf26e1c5bfbf0e2
#       Build dir: C:\Users\Olive\AppData\Local\Temp\pip-install-rq_w22ba\numpy_7879cad0f7b84bb99bf26e1c5bfbf0e2\.mesonpy-krpvwi7m
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not parse vswhere.exe output
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `cl /?` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `cc --version` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `gcc --version` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `clang --version` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `clang-cl /?` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#       Running `pgcc --version` gave "[WinError 2] O sistema não pode encontrar o arquivo especificado"
#
#       A full log can be found at C:\Users\Olive\AppData\Local\Temp\pip-install-rq_w22ba\numpy_7879cad0f7b84bb99bf26e1c5bfbf0e2\.mesonpy-krpvwi7m\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
