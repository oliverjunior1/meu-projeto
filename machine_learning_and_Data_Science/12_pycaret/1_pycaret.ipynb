# %% [markdown]
# # Guia Completo de PyCaret com 5 Exemplos
#
# ## O que é PyCaret?
#
# PyCaret é uma biblioteca low-code de Machine Learning para Python.
#
# Ela automatiza:
# - treinamento;
# - comparação de modelos;
# - preprocessamento;
# - previsão;
# - análise de dados.
#
# Com poucas linhas de código é possível criar modelos completos.

# %% [markdown]
# # Instalação
#
# ```python
# pip install pycaret
# ```
#
# ou:
#
# ```python
# pip install pycaret[full]
# ```

# %% [markdown]
# # Exemplo 1 - Classificação
#
# ## Objetivo
# Prever categorias.
#
# Exemplos:
# - spam;
# - fraude;
# - aprovação de crédito.

# %%
! pip install pycaret
# Out:
# Collecting pycaret
#   Using cached pycaret-3.3.2-py3-none-any.whl.metadata (17 kB)
# Collecting ipython>=5.5.0 (from pycaret)
#   Using cached ipython-9.13.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting ipywidgets>=7.6.5 (from pycaret)
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting tqdm>=4.62.0 (from pycaret)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting numpy<1.27,>=1.21 (from pycaret)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\Olive\AppData\Local\Programs\Python\Python313\python.exe C:\Users\Olive\AppData\Local\Temp\pip-install-zdas8u5a\numpy_1ffa69d8bd864e378d8ab9426fcc17fc\vendored-meson\meson\meson.py setup C:\Users\Olive\AppData\Local\Temp\pip-install-zdas8u5a\numpy_1ffa69d8bd864e378d8ab9426fcc17fc C:\Users\Olive\AppData\Local\Temp\pip-install-zdas8u5a\numpy_1ffa69d8bd864e378d8ab9426fcc17fc\.mesonpy-d1odh2i6 -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\Olive\AppData\Local\Temp\pip-install-zdas8u5a\numpy_1ffa69d8bd864e378d8ab9426fcc17fc\.mesonpy-d1odh2i6\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\Olive\AppData\Local\Temp\pip-install-zdas8u5a\numpy_1ffa69d8bd864e378d8ab9426fcc17fc
#       Build dir: C:\Users\Olive\AppData\Local\Temp\pip-install-zdas8u5a\numpy_1ffa69d8bd864e378d8ab9426fcc17fc\.mesonpy-d1odh2i6
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not parse vswhere.exe output
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `cl /?` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `cc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `gcc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `clang --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `clang-cl /?` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `pgcc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#
#       A full log can be found at C:\Users\Olive\AppData\Local\Temp\pip-install-zdas8u5a\numpy_1ffa69d8bd864e378d8ab9426fcc17fc\.mesonpy-d1odh2i6\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
! pip install pycaret[full]
# Out:
# Collecting pycaret[full]
#   Using cached pycaret-3.3.2-py3-none-any.whl.metadata (17 kB)
# Collecting ipython>=5.5.0 (from pycaret[full])
#   Using cached ipython-9.13.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting ipywidgets>=7.6.5 (from pycaret[full])
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting tqdm>=4.62.0 (from pycaret[full])
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting numpy<1.27,>=1.21 (from pycaret[full])
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\Olive\AppData\Local\Programs\Python\Python313\python.exe C:\Users\Olive\AppData\Local\Temp\pip-install-3j3cmesr\numpy_73d70ebf08c04e289d072da27fefcf63\vendored-meson\meson\meson.py setup C:\Users\Olive\AppData\Local\Temp\pip-install-3j3cmesr\numpy_73d70ebf08c04e289d072da27fefcf63 C:\Users\Olive\AppData\Local\Temp\pip-install-3j3cmesr\numpy_73d70ebf08c04e289d072da27fefcf63\.mesonpy-pdkuu6ub -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\Olive\AppData\Local\Temp\pip-install-3j3cmesr\numpy_73d70ebf08c04e289d072da27fefcf63\.mesonpy-pdkuu6ub\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\Olive\AppData\Local\Temp\pip-install-3j3cmesr\numpy_73d70ebf08c04e289d072da27fefcf63
#       Build dir: C:\Users\Olive\AppData\Local\Temp\pip-install-3j3cmesr\numpy_73d70ebf08c04e289d072da27fefcf63\.mesonpy-pdkuu6ub
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not parse vswhere.exe output
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `cl /?` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `cc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `gcc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `clang --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `clang-cl /?` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#       Running `pgcc --version` gave "[WinError 2] O sistema nÃ£o pode encontrar o arquivo especificado"
#
#       A full log can be found at C:\Users\Olive\AppData\Local\Temp\pip-install-3j3cmesr\numpy_73d70ebf08c04e289d072da27fefcf63\.mesonpy-pdkuu6ub\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import sys

# !{sys.executable} -m pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (9.13.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (8.1.8)
# Requirement already satisfied: tqdm>=4.62.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (4.67.3)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (3.4.0)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (0.14.1)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (0.62.1)
# Requirement already satisfied: requests>=2.27.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (2.34.2)
# Requirement already satisfied: psutil>=5.9.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (7.2.2)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (9.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: deprecation>=2.1.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (3.7.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (6.7.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (1.3.0)
# Requirement already satisfied: schemdraw==0.15 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (0.14.6)
# Requirement already satisfied: sktime==0.26.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from sktime==0.26.0->pycaret) (26.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from matplotlib<3.8.0->pycaret) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from matplotlib<3.8.0->pycaret) (1.5.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from matplotlib<3.8.0->pycaret) (12.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from matplotlib<3.8.0->pycaret) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pandas<2.2.0->pycaret) (2026.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pandas<2.2.0->pycaret) (2026.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from scikit-learn>1.4.0->pycaret) (3.6.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (0.1.5)
# Requirement already satisfied: zipp>=3.20 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (4.1.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (5.15.0)
# Requirement already satisfied: typing_extensions>=4.6 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipython>=5.5.0->pycaret) (4.15.0)
# Requirement already satisfied: wcwidth in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: comm>=0.1.3 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from jedi>=0.18.2->ipython>=5.5.0->pycaret) (0.8.7)
# Requirement already satisfied: choreographer>=1.3.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from kaleido>=0.2.1->pycaret) (1.3.0)
# Requirement already satisfied: logistro>=1.0.8 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from kaleido>=0.2.1->pycaret) (3.11.9)
# Requirement already satisfied: platformdirs>=4.3.6 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from choreographer>=1.3.0->kaleido>=0.2.1->pycaret) (4.9.6)
# Requirement already satisfied: simplejson>=3.19.3 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from choreographer>=1.3.0->kaleido>=0.2.1->pycaret) (4.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from nbformat>=4.2.0->pycaret) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from nbformat>=4.2.0->pycaret) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from nbformat>=4.2.0->pycaret) (5.9.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from numba>=0.55.0->pycaret) (0.45.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from plotly>=5.14.0->pycaret) (2.21.2)
# Requirement already satisfied: dash>=2.11.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (4.1.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.3.3)
# Requirement already satisfied: Werkzeug<3.2 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.3.8)
# Requirement already satisfied: retrying in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: setuptools in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (82.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.4.1)
# Requirement already satisfied: blinker>=1.6.2 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.2.5)
# Requirement already satisfied: urllib3 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from pmdarima>=2.0.4->pycaret) (1.26.20)
# Requirement already satisfied: six>=1.5 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from requests>=2.27.1->pycaret) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from requests>=2.27.1->pycaret) (3.16)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from requests>=2.27.1->pycaret) (2026.5.20)
# Requirement already satisfied: executing>=1.2.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (3.0.1)
# Requirement already satisfied: pure-eval in c:\Users\Olive\Anaconda\envs\pycaret311\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (0.2.3)

# %%
from pycaret.classification import *
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

base = pd.DataFrame(iris.data, columns=iris.feature_names)
base['target'] = iris.target

base.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
clf = setup(data=base, target='target', session_id=123)
# Out:
# <style type="text/css">
# #T_be047_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_be047">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be047_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_be047_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be047_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be047_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_be047_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be047_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_be047_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be047_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_be047_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be047_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_be047_row3_col1" class="data row3 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be047_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_be047_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be047_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_be047_row5_col1" class="data row5 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be047_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_be047_row6_col1" class="data row6 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be047_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_be047_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be047_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_be047_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be047_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_be047_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_be047_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_be047_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_be047_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_be047_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_be047_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_be047_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_be047_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_be047_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_be047_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_be047_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_be047_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_be047_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_be047_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_be047_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_be047_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_be047_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_be047_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_be047_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_be047_row18_col1" class="data row18 col1" >fdce</td>
#     </tr>
#   </tbody>
# </table>

# %%
melhor_modelo = compare_models()
# Out:
# <style type="text/css">
# #T_2acfb th {
#   text-align: left;
# }
# #T_2acfb_row0_col0, #T_2acfb_row0_col2, #T_2acfb_row1_col0, #T_2acfb_row1_col2, #T_2acfb_row2_col0, #T_2acfb_row2_col2, #T_2acfb_row3_col0, #T_2acfb_row3_col2, #T_2acfb_row4_col0, #T_2acfb_row4_col1, #T_2acfb_row4_col3, #T_2acfb_row4_col4, #T_2acfb_row4_col5, #T_2acfb_row4_col6, #T_2acfb_row4_col7, #T_2acfb_row5_col0, #T_2acfb_row5_col1, #T_2acfb_row5_col2, #T_2acfb_row5_col3, #T_2acfb_row5_col4, #T_2acfb_row5_col5, #T_2acfb_row5_col6, #T_2acfb_row5_col7, #T_2acfb_row6_col0, #T_2acfb_row6_col1, #T_2acfb_row6_col3, #T_2acfb_row6_col4, #T_2acfb_row6_col5, #T_2acfb_row6_col6, #T_2acfb_row6_col7, #T_2acfb_row7_col0, #T_2acfb_row7_col1, #T_2acfb_row7_col2, #T_2acfb_row7_col3, #T_2acfb_row7_col4, #T_2acfb_row7_col5, #T_2acfb_row7_col6, #T_2acfb_row7_col7, #T_2acfb_row8_col0, #T_2acfb_row8_col1, #T_2acfb_row8_col2, #T_2acfb_row8_col3, #T_2acfb_row8_col4, #T_2acfb_row8_col5, #T_2acfb_row8_col6, #T_2acfb_row8_col7, #T_2acfb_row9_col0, #T_2acfb_row9_col1, #T_2acfb_row9_col2, #T_2acfb_row9_col3, #T_2acfb_row9_col4, #T_2acfb_row9_col5, #T_2acfb_row9_col6, #T_2acfb_row9_col7, #T_2acfb_row10_col0, #T_2acfb_row10_col1, #T_2acfb_row10_col2, #T_2acfb_row10_col3, #T_2acfb_row10_col4, #T_2acfb_row10_col5, #T_2acfb_row10_col6, #T_2acfb_row10_col7, #T_2acfb_row11_col0, #T_2acfb_row11_col1, #T_2acfb_row11_col2, #T_2acfb_row11_col3, #T_2acfb_row11_col4, #T_2acfb_row11_col5, #T_2acfb_row11_col6, #T_2acfb_row11_col7, #T_2acfb_row12_col0, #T_2acfb_row12_col1, #T_2acfb_row12_col2, #T_2acfb_row12_col3, #T_2acfb_row12_col4, #T_2acfb_row12_col5, #T_2acfb_row12_col6, #T_2acfb_row12_col7, #T_2acfb_row13_col0, #T_2acfb_row13_col1, #T_2acfb_row13_col2, #T_2acfb_row13_col3, #T_2acfb_row13_col4, #T_2acfb_row13_col5, #T_2acfb_row13_col6, #T_2acfb_row13_col7, #T_2acfb_row14_col0, #T_2acfb_row14_col1, #T_2acfb_row14_col2, #T_2acfb_row14_col3, #T_2acfb_row14_col4, #T_2acfb_row14_col5, #T_2acfb_row14_col6, #T_2acfb_row14_col7 {
#   text-align: left;
# }
# #T_2acfb_row0_col1, #T_2acfb_row0_col3, #T_2acfb_row0_col4, #T_2acfb_row0_col5, #T_2acfb_row0_col6, #T_2acfb_row0_col7, #T_2acfb_row1_col1, #T_2acfb_row1_col3, #T_2acfb_row1_col4, #T_2acfb_row1_col5, #T_2acfb_row1_col6, #T_2acfb_row1_col7, #T_2acfb_row2_col1, #T_2acfb_row2_col3, #T_2acfb_row2_col4, #T_2acfb_row2_col5, #T_2acfb_row2_col6, #T_2acfb_row2_col7, #T_2acfb_row3_col1, #T_2acfb_row3_col3, #T_2acfb_row3_col4, #T_2acfb_row3_col5, #T_2acfb_row3_col6, #T_2acfb_row3_col7, #T_2acfb_row4_col2, #T_2acfb_row6_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2acfb_row0_col8, #T_2acfb_row1_col8, #T_2acfb_row2_col8, #T_2acfb_row4_col8, #T_2acfb_row5_col8, #T_2acfb_row6_col8, #T_2acfb_row7_col8, #T_2acfb_row8_col8, #T_2acfb_row9_col8, #T_2acfb_row10_col8, #T_2acfb_row11_col8, #T_2acfb_row12_col8, #T_2acfb_row13_col8, #T_2acfb_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2acfb_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2acfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2acfb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2acfb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_2acfb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_2acfb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_2acfb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_2acfb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_2acfb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_2acfb_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_2acfb_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2acfb_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_2acfb_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_2acfb_row0_col1" class="data row0 col1" >0.9718</td>
#       <td id="T_2acfb_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_2acfb_row0_col3" class="data row0 col3" >0.9718</td>
#       <td id="T_2acfb_row0_col4" class="data row0 col4" >0.9780</td>
#       <td id="T_2acfb_row0_col5" class="data row0 col5" >0.9712</td>
#       <td id="T_2acfb_row0_col6" class="data row0 col6" >0.9573</td>
#       <td id="T_2acfb_row0_col7" class="data row0 col7" >0.9609</td>
#       <td id="T_2acfb_row0_col8" class="data row0 col8" >2.3900</td>
#     </tr>
#     <tr>
#       <th id="T_2acfb_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_2acfb_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_2acfb_row1_col1" class="data row1 col1" >0.9718</td>
#       <td id="T_2acfb_row1_col2" class="data row1 col2" >0.9830</td>
#       <td id="T_2acfb_row1_col3" class="data row1 col3" >0.9718</td>
#       <td id="T_2acfb_row1_col4" class="data row1 col4" >0.9780</td>
#       <td id="T_2acfb_row1_col5" class="data row1 col5" >0.9712</td>
#       <td id="T_2acfb_row1_col6" class="data row1 col6" >0.9573</td>
#       <td id="T_2acfb_row1_col7" class="data row1 col7" >0.9609</td>
#       <td id="T_2acfb_row1_col8" class="data row1 col8" >0.7430</td>
#     </tr>
#     <tr>
#       <th id="T_2acfb_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_2acfb_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_2acfb_row2_col1" class="data row2 col1" >0.9718</td>
#       <td id="T_2acfb_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_2acfb_row2_col3" class="data row2 col3" >0.9718</td>
#       <td id="T_2acfb_row2_col4" class="data row2 col4" >0.9780</td>
#       <td id="T_2acfb_row2_col5" class="data row2 col5" >0.9712</td>
#       <td id="T_2acfb_row2_col6" class="data row2 col6" >0.9573</td>
#       <td id="T_2acfb_row2_col7" class="data row2 col7" >0.9609</td>
#       <td id="T_2acfb_row2_col8" class="data row2 col8" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_2acfb_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_2acfb_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_2acfb_row3_col1" class="data row3 col1" >0.9718</td>
#       <td id="T_2acfb_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_2acfb_row3_col3" class="data row3 col3" >0.9718</td>
#       <td id="T_2acfb_row3_col4" class="data row3 col4" >0.9780</td>
#       <td id="T_2acfb_row3_col5" class="data row3 col5" >0.9712</td>
#       <td id="T_2acfb_row3_col6" class="data row3 col6" >0.9573</td>
#       <td id="T_2acfb_row3_col7" class="data row3 col7" >0.9609</td>
#       <td id="T_2acfb_row3_col8" class="data row3 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_2acfb_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_2acfb_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2acfb_row4_col1" class="data row4 col1" >0.9536</td>
#       <td id="T_2acfb_row4_col2" class="data row4 col2" >0.9935</td>
#       <td id="T_2acfb_row4_col3" class="data row4 col3" >0.9536</td>
#       <td id="T_2acfb_row4_col4" class="data row4 col4" >0.9634</td>
#       <td id="T_2acfb_row4_col5" class="data row4 col5" >0.9528</td>
#       <td id="T_2acfb_row4_col6" class="data row4 col6" >0.9298</td>
#       <td id="T_2acfb_row4_col7" class="data row4 col7" >0.9356</td>
#       <td id="T_2acfb_row4_col8" class="data row4 col8" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_2acfb_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_2acfb_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_2acfb_row5_col1" class="data row5 col1" >0.9445</td>
#       <td id="T_2acfb_row5_col2" class="data row5 col2" >0.9868</td>
#       <td id="T_2acfb_row5_col3" class="data row5 col3" >0.9445</td>
#       <td id="T_2acfb_row5_col4" class="data row5 col4" >0.9525</td>
#       <td id="T_2acfb_row
