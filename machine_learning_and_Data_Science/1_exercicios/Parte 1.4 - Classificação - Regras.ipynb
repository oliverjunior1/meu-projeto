# %%
# !pip install Orange3
# Out:
# Requirement already satisfied: Orange3 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.40.0)
# Requirement already satisfied: AnyQt>=0.2.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (0.2.1)
# Requirement already satisfied: baycomp>=1.0.2 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (1.0.3)
# Requirement already satisfied: bottleneck>=1.3.4 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (1.6.0)
# Requirement already satisfied: chardet>=3.0.2 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (7.3.0)
# Requirement already satisfied: httpx<1,>=0.21.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (0.28.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (1.5.3)
# Requirement already satisfied: keyring in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (25.7.0)
# Requirement already satisfied: keyrings.alt in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (5.0.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (3.9.0rc2)
# Requirement already satisfied: networkx in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (3.6.1)
# Requirement already satisfied: numpy<2.4,>=1.21.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (1.26.4)
# Requirement already satisfied: openTSNE!=0.7.0,>=0.6.2 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (1.0.4)
# Requirement already satisfied: openpyxl>=3.1.3 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (3.1.5)
# Requirement already satisfied: orange-canvas-core<0.3a,>=0.2.5 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (0.2.8)
# Requirement already satisfied: orange-widget-base>=4.25.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (4.27.0)
# Requirement already satisfied: packaging in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (24.0)
# Requirement already satisfied: pandas<3,>=2.0.1 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (2.2.2)
# Requirement already satisfied: pygments>=2.8.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (2.18.0)
# Requirement already satisfied: pyqtgraph>=0.13.1 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (0.14.0)
# Requirement already satisfied: python-louvain>=0.13 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (0.16)
# Requirement already satisfied: pyyaml in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (6.0.3)
# Requirement already satisfied: qtconsole>=4.7.2 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (5.7.2)
# Requirement already satisfied: requests in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.5.1 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (1.8.0)
# Requirement already satisfied: scipy>=1.9 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (1.14.0rc1)
# Requirement already satisfied: serverfiles in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (0.3.1)
# Requirement already satisfied: xgboost>=1.7.4 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (3.2.0)
# Requirement already satisfied: xlrd>=1.2.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (2.0.2)
# Requirement already satisfied: xlsxwriter in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Orange3) (3.2.9)
# Requirement already satisfied: anyio in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1,>=0.21.0->Orange3) (4.13.0)
# Requirement already satisfied: certifi in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1,>=0.21.0->Orange3) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1,>=0.21.0->Orange3) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1,>=0.21.0->Orange3) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.21.0->Orange3) (0.16.0)
# Requirement already satisfied: docutils in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (0.21.2)
# Requirement already satisfied: commonmark>=0.8.1 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (0.9.1)
# Requirement already satisfied: requests-cache in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (1.3.1)
# Requirement already satisfied: pip>=18.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (26.0.1)
# Requirement already satisfied: dictdiffer in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (0.9.0)
# Requirement already satisfied: qasync>=0.10.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (0.28.0)
# Requirement already satisfied: typing_extensions in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (4.15.0)
# Requirement already satisfied: truststore in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from orange-canvas-core<0.3a,>=0.2.5->Orange3) (0.10.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas<3,>=2.0.1->Orange3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas<3,>=2.0.1->Orange3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas<3,>=2.0.1->Orange3) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->Orange3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->Orange3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->Orange3) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->Orange3) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->Orange3) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->Orange3) (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from openpyxl>=3.1.3->Orange3) (1.1.0)
# Requirement already satisfied: colorama in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pyqtgraph>=0.13.1->Orange3) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=2.0.1->Orange3) (1.16.0)
# Requirement already satisfied: traitlets!=5.2.1,!=5.2.2 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from qtconsole>=4.7.2->Orange3) (5.14.3)
# Requirement already satisfied: jupyter_core in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from qtconsole>=4.7.2->Orange3) (5.9.1)
# Requirement already satisfied: jupyter_client>=4.1 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from qtconsole>=4.7.2->Orange3) (8.8.0)
# Requirement already satisfied: ipykernel>=4.1 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from qtconsole>=4.7.2->Orange3) (7.2.0)
# Requirement already satisfied: ipython_pygments_lexers in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from qtconsole>=4.7.2->Orange3) (1.1.1)
# Requirement already satisfied: qtpy>=2.4.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from qtconsole>=4.7.2->Orange3) (2.4.3)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (9.11.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (6.5.5)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (5.2.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.8.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jupyter_core->qtconsole>=4.7.2->Orange3) (4.2.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn>=1.5.1->Orange3) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\Olive\AppData\Roaming\Python\Python312\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=4.1->qtconsole>=4.7.2->Orange3) (0.2.3)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keyring->Orange3) (0.2.3)
# Requirement already satisfied: jaraco.classes in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keyring->Orange3) (3.4.0)
# Requirement already satisfied: jaraco.functools in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keyring->Orange3) (4.4.0)
# Requirement already satisfied: jaraco.context in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keyring->Orange3) (6.1.2)
# Requirement already satisfied: more-itertools in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jaraco.classes->keyring->Orange3) (11.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests->Orange3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests->Orange3) (2.2.1)
# Requirement already satisfied: attrs>=21.2 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests-cache->orange-canvas-core<0.3a,>=0.2.5->Orange3) (26.1.0)
# Requirement already satisfied: cattrs>=22.2 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests-cache->orange-canvas-core<0.3a,>=0.2.5->Orange3) (26.1.0)
# Requirement already satisfied: url-normalize>=2.0 in c:\Users\Olive\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests-cache->orange-canvas-core<0.3a,>=0.2.5->Orange3) (2.2.1)

# %%
import Orange
Orange.__version__
# Out:
# '3.40.0'

# %% [markdown]
# ---
#
# Reconecte ao Drive.

# %%
import os
DRIVE_DIRECTORY = "curso_ml"
DRIVE_DIRECTORY = os.path.join("/content/drive/MyDrive", DRIVE_DIRECTORY)

# %% [markdown]
# ---

# %%
import pickle

from collections import Counter

import pandas as pd
import seaborn as sns

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# # Regras

# %% [markdown]
# Para gerar regras, nós precisamos começar com o arquivo com os dados originais, `cov_types.csv`, que deve estar salvo na sua pasta do Drive.
#
# Primeiro recarregue esse arquivo com o Pandas.

# %%
base = pd.read_csv()
base

# %% [markdown]
# Agora, lembre-se que a coluna com a classe deve ser indicada pelo prefixo `c#`. Então, vamos renomear a coluna `Cover_Type` para ficar neste formato.

# %%
base.ren___(columns={"Cover_Type": ___}, inplace=___)
base

# %% [markdown]
# Salve o arquivo modificado. Como você só vai utilizar este arquivo neste exercício, não precisa salvar no Drive.

# %%
base.___('cov_types.csv', index=False)

# %% [markdown]
# Gere uma instância da classe `Orange.data.Table` informando o arquivo `csv` contendo os dados.

# %%
base = ___(___)

# %% [markdown]
# Exiba o domínio desta base.

# %%
base.___

# %% [markdown]
# Utilize o método adequado da biblioteca Orange para separar 25% dos dados da base em um split de teste, e o restante em um split de treinamento. Você pode salvar o resultado da função diretamente nas variáveis dos splits correspondentes, observando que o split de teste é retornado primeiro.

# %%
base_te___, base_tr___ = ___(___, n=___)

# %% [markdown]
# Verifique o tamanho desses splits.

# %%
len(base_tr___), len(___)

# %% [markdown]
# Instancie e ajuste um classificador do tipo `CN2Learner`.

# %%
cn2_classifier = ___
rules = ___(___)

# %% [markdown]
# Observe que, como esta base é maior, o número de regras é bastante elevado:

# %%
len(rules.rule_list)

# %% [markdown]
# Então, vamos visualizar somente as 10 primeiras regras:

# %%
for i, ___ in enumerate(___):
    print(___)
    if i == 10:
        break

# %% [markdown]
# Faça predições informando ao algoritmo a base de teste.

# %%
y_pred = ___(___)
y_pred

# %% [markdown]
# Observe que nós podemos recuperar os valores reais através do atributo `Y` de `base_test`.

# %%
y_test = base_test.Y
y_test

# %% [markdown]
# Utilize este valor para calcular a acurácia do modelo.

# %%
___

# %% [markdown]
# Desta vez você deve utilizar a função `confusion_matrix` do `sklearn` para exibir a matriz de confusão no formato de um array. Esta função recebe primeiro os valores reais, depois os valores preditos.

# %%
cm = confusion_matrix(y_te___, y_pr___)
cm

# %% [markdown]
# Você pode gerar um gráfico da matriz de confusão similar ao do yellowbrick com a função `sns.heatmap`:

# %%
sns.heatmap(cm,
            annot=True, # para exibir as contagens nas células do gráfico
            fmt='d', # para que os valores sejam em formato inteiro
            cmap='YlOrRd', # o mesmo mapa de cor do yellowbrick
            mask = (cm == 0) # não exibe os valores e a cor onde o valor for igual a 0
            );

# %% [markdown]
# Exiba o reporte de classificação do modelo.

# %%
___

# %% [markdown]
# ## Classificador base (majority learner)

# %% [markdown]
# Implemente um classificador do tipo `MajorityLearner`.

# %%
majority = ___

# %% [markdown]
# Faça predições para a base inteira com base nesse classificador.

# %%
y_test = ___

# %% [markdown]
# Exiba a acurácia deste classificador.

# %%
___

# %% [markdown]
# Exiba o número de registros em cada classe na base inteira.

# %%
___

# %% [markdown]
# Veja que a base tem 10 mil registros:

# %%
len(base)

# %% [markdown]
# Isso significa que a classe majoritária, *Lodgepole Pine*, representa $4847/10000=0.4847\%$ dos dados, ou seja, exatamente a acurácia alcançada pelo classificador base do tipo *majority learner*.
