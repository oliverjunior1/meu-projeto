# %% [markdown]
# ### Reconecte ao Drive

# %%
import os
DRIVE_DIRECTORY = "curso_ml"
DRIVE_DIRECTORY = os.path.join("/content/drive/MyDrive/curso_ml", DRIVE_DIRECTORY)

# %%
import pickle

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Base de dados cobertura vegetal

# %% [markdown]
# Neste exercício você vai mais uma vez utilizar a base de dados cobertura vegetal

# %% [markdown]
# Carregue o arquivo csv salvo na pasta do Drive. Visualize o DataFrame resultante.

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 import os
# ----> 3 os.listdir(r"C:\Users\SeuUsuario\Documents\curso_ml")
#
# FileNotFoundError: [WinError 3] O sistema não pode encontrar o caminho especificado: 'C:\\Users\\SeuUsuario\\Documents\\curso_ml'
